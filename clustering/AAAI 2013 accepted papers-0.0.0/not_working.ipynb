# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('AAAI-13 Accepted Papers - Papers.csv')
data
# Out:
#                                                  Title  \
# 0    The cascade auction – a mechanism for deterrin...
# 1    Basis Adaptation for Sparse Nonlinear Reinforc...
# 2    Optimal Coalition Structures in Cooperative Gr...
# 3    External Memory Best-First Search for Multiple...
# 4    Posted Prices Exchange for Display Advertising...
# 5    Gradient Networks for Shape-Based Object Insta...
# 6    Unified Constraint Propagation on Multi-View Data
# 7    Progression of Decomposed Situation Calculus T...
# 8              How to Cut a Cake Before the Party Ends
# 9    Reciprocal Hash Tables for Nearest Neighbor Se...
# 10                        Automated Workflow Synthesis
# 11   Video Saliency Detection via Dynamic Consisten...
# 12          Symmetry-Aware Marginal Density Estimation
# 13   Improving WalkSAT for Random $k$-Satisfiabilit...
# 14   A Generalized Student-t Based Approach to Mixe...
# 15    Causal Transportability with Limited Experiments
# ...

# %%
le = LabelEncoder()
le.fit(data['High-Level Keyword(s)'])
HLK_std = le.transform(data['High-Level Keyword(s)'])
le.fit(data['Keywords'])
K_std = le.transform(data['Keywords'])
a = np.array(HLK_std)
b = np.array(K_std)
c = [a,b]
c1 = np.array(c)
c1 = c1.transpose()
HLK_std,K_std,a,c,HLK_std.shape,K_std.shape,c1.shape
#words = np.concatenate(HLK_std,K_std)
# Out:
# (array([43, 41, 43, 11, 43, 57, 33, 21, 43, 14, 45, 49, 41,  5, 33, 28, 33,
#         43, 48, 43, 44,  8, 33, 56, 46, 33, 10, 36, 21, 43, 11, 26, 33,  1,
#         28, 21, 33,  0, 12, 43, 33, 33, 33, 15, 30, 33, 34,  2,  7, 43, 43,
#         15, 18,  9, 33, 43, 57, 52, 47, 21, 34, 50, 22, 38, 52, 33,  2, 43,
#         26, 33, 43, 19, 33,  9, 21,  4, 43, 31, 52, 48, 33, 21, 47,  3, 33,
#         56, 43, 37,  2, 33, 52, 33, 21, 51, 35, 43, 43, 34, 16,  6, 33, 33,
#         15, 33, 33, 24, 41, 25, 54, 33, 33, 34, 13,  2, 42, 38, 43, 36, 28,
#         39, 27, 46, 23, 43, 47, 16, 36,  5, 24, 20, 52, 29, 36, 36,  2, 43,
#         17, 33, 33, 55, 44, 38, 40, 33, 33, 52, 43, 52, 53, 32]),
#  array([ 56,  80,  22,  30,  26, 131, 133, 139,   9, 123, 117, 102, 143,
#         103,  68,  10,  75,  16,  36,   8,  23,  41,  20,  73,  44,  13,
#          91, 126,  77,  64,   6,   7,  48, 101,   4, 107,  33,  43, 135,
#          19,  15, 141,  63,  39,  25, 142, 115, 112, 104,  17,  58,  60,
# ...

# %%
clu = KMeans()
clu.fit(data_std)
y_pred = clu.predict(c1)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-51e779fa9245> in <module>()
#       1 clu = KMeans()
# ----> 2 clu.fit(data_std)
#       3 y_pred = clu.predict(c1)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     878         """
#     879         random_state = check_random_state(self.random_state)
# --> 880         X = self._check_fit_data(X)
#     881
#     882         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# ...
